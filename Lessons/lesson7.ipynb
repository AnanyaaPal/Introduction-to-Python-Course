# %% [markdown]
# #| label: intro
#
# # Course material 6
# ## Lesson 7 (23.11.2023)

# %% [markdown]
# ### Working with *Spyder*
#
# #### The core panes in Spyder
#
# + open Anaconda Navigator and click on the Spyder application (before you can *launch* it, you have to *install* it)
# + divided into three sections showing three different panes:
#     + the Editor,
#     + the IPython Console and
#     + the Help viewer.
#
# + These three, along with the Variable Explorer, are the four core panes you’ll work with the most in Spyder.

# %%
from IPython.display import Image
from IPython.core.display import HTML 

PATH = "graphics/"
Image(filename = PATH + "spyder_layout.png", width=600)

# %% [markdown]
# + On the left we have the **Editor**, where you can open, edit and run files.
# + Bottom right is the **IPython Console**, which you can use both interactively and to run your code in the Editor.
# + Above the IPhython Console, you’ll find the **Help pane**, where you can get more information and documentation for any object in the Editor or Console by pressing `Ctrl-I` (or `Cmd-I` on macOS).
#
# For the two sections on the right, you can switch tabs.
#
# + In the top section, you can switch to
#     + the **Variable Explorer**, which shows you the name, type, size and value of the variables that you have previously defined in the Editor or the Console. You can also modify the value of these variables directly from this pane by double clicking them under the Value column.
#     + the **Plots pane** will show you the figures you generate with Matplotlib and other libraries, and
#     + the **Files pane** allows you to browse the files on your computer and open them in the Editor with just a click.
# + In the bottom section you can also access
#     + the **History pane**, which shows you the commands you have entered in the Console, including those from previous sessions.

# %%
Image(filename = PATH + "spyder_toolbar.png")

# %% [markdown]
# #### The toolbar
#
# 1. new file
# 2. open file
# 3. save file
# 4. save all files
# 5. run whole file
# 6. run current cell
# 7. run current cell and go the next one
# 8. run selection or current line

# %% [markdown]
# #### Getting started
#
# **Running Code**
#
# + create a new .py-file by clicking on the file icon in upper left toolbar (icon 1.)
# + type ``print("Hello World")`` into the editor and run the whole file by clicking on the run button (icon 5.)
# + We can see in the Python Console
#     + the output,
#     + the path of the file that we are running and
#     + the working directory where this code was run.
#
# + You can also run code
#     + of a single line instead of the whole script: go into the respective line and press `F9` (shortcut variant) or click on the run selection button in the toolbar (icon 8.)
#     + of a *cell* in the python file:
#         + go to the editor and type below `print("Hello World")` the following lines:

# %%
#%% first cell
print("This is cell 1")

#%% second cell
print("This is cell 2")

#%%
# Out:
# This is cell 1
# This is cell 2

# %% [markdown]
# + You can also run code
#     + of a *cell* in the python file...:
#         + Now, go in to the line with `#%% first cell` and press the run current cell button (icon 6.)
#         + if you want to current the current cell and directly jump to the next cell you can use (icon 7.)
#     + directly in the IPython Console (type "Hello world" in the Console and hit enter)
#
# + (A summary of all shortcuts can by found in `Help > Shortcuts Summary`)
#
# **Defining variables**
#
# + you can define variables from both, the editor or the console:
#     + type `a = 10` below the last `#%%` in your file and run the line (icon 8. or F9)
#     + type `b = 20` in the IPython console and hit enter
# + now switch the tab in the upper right `Help Pane` to `Variable Explorer`
#     + for both variables `a` and `b` you see the name, type, size and value
#
# + Next, define a list in the editor below `a = 10` by typing `l = [1, 2, 3]` and run the line
# + You can see in the `Variable Explorer` that the type of the variable is list and the size is 3.
#
# **Changing and removing variable values**
#
# + We can **change the values** of the variables in the Variable Explorer too
#     + double-click on `a`, change the value to `30` and hit enter
#     + now type the variable in the IPyhton Console and check that the value of `a` has indeed changed
#     + changing more complex types, e.g. a list, will open a viewer, try it out: double-click on `l` and change the third value to `4`, then type `l` in the IPython Console and check whether it has really the values `l = [1,2,4]`
# + Next, we **remove** the variable `b`
#     + variant 1) right-click on the variable `b` in the Variable Explorer and selecting the option Remove
#     + variant 2) type in the IPython Console `del b`
# + Check in the IPthon Console whether the variable was actually deleted (i.e., you should get an error message indicating that b is not defined)
#
# **Getting help**
#
# + import numpy and define a new variable:
#     + import numpy in the python script by typing `import numpy as np`
#     + define a new variable: `v = np.array([1,2,3])`
#     + select and run both lines (use `F9`)
# + you can get `help` for an object in two ways:
#     + select the written object in your file and press `Ctrl-I` (or `Cmd-I` on macOS): try it for `np.array`
#     + in the help pane, select the tab `Help`, then you will find in the upper part of the pane a Source dropdown option. Change it to from *Editor* to *Console* and type `np.array` in the *Object* box
#
# The python file should look as follows:

# %%
print("Hello World")

#%% first cell
print("This is cell 1")

#%% second cell
print("This is cell 2")

#%%

# define variables
a = 10
l = [1,2,3]

# import the numpy library
import numpy as np
v = np.array([1,2,3])
# Out:
# Hello World
# This is cell 1
# end of cell 1
# This is cell 2

# %% [markdown]
# #### Customize Spyder
#
# **Font**
# + go to *Tools > Preferences* and select the *Appearance* entry. In the bottom you will find the section *Fonts*.
# + You can change both the style and the size of the font for both plain and rich text.
# + When you press the `Apply` button in the lower right, you can directly see how the change looks like
#
# **syntax highlighting theme**
# + in the same dialog, you find also the section *syntax highlighting theme*
# + choosing a theme will show you directly in the preview how it looks like
# + select a theme and the click `Apply` to restart Spyder to apply the new theme.
#
# **Select/Rearrange Panes**
# + you can also rearrange the panes in Spyder’s main window
# + Go to *View > Panes*: here you can select which panes you want to see.
# + By default, the panes and toolbars are locked so they can’t be moved accidentally.
# + In *View > Unlock panes and toolbars* allows you to move them freely anywhere on the window by dragging them from the top and dropping them at any position you like.
#
# **Further customization options for each pane**
# + Go to *Tools > Preferences* and select the *Editor* entry. Here further adjust the editor appearance (the same is possible for the other panes of course)
#
# **Back to the roots**
# + if you ever want to return to its default configuration, you can always reset the window layout under *View > Window Layouts* or your entire Spyder configuration in *Tools > Preferences* with the `Reset to Defaults` button in the lower left corner.
#
# ### Create a new script and write a new class

# %%
import requests
import os
import pathlib
import polars as pl
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


class PolitenessData():
    def __init__(self, data_url, target_path, data_file):
        """Download, preprocess, and plot politeness data from Bodo Winter

        Parameters
        ----------
        data_url : str 
            Url from where to download the data set.
        target_path : str
            local working directory where data should be stored.
        data_file : str
            name of file to which data should be saved.

        Returns
        -------
        cwd : str
            Information about the current working directory.
        summary_stats : DataFrame
            Summary statistics of the politeness data.
        plot : plt.plot
            Plot of the politeness data.

        """
        self.target_path = target_path
        self.data_url = data_url
        self.data_file = data_file
        
    def __call__(self):

        # set current working directory   
        self.set_cwd(self.target_path)
        # download data set from specified url
        self.download_data(self.data_url, file_name = self.data_file)
        # read and preprocess data set
        df, summary_stats = self.data_preprocessed(self.data_file)
        # show summary statistics
        print(summary_stats)
        # plot data
        self.plot_data(df)
  
    def set_cwd(self, target_path):
        """Set current working directory to desired local path

        Parameters
        ----------
        target_path : str
            local path that should be used as current working directory.

        Returns
        -------
        current_working_directory : str
            Prints current working directory.

        """
        # set the current working directory 
        os.chdir(target_path)
        
        # get current working directory
        current_wd = pathlib.Path.cwd()
        # check whether current working directory is indeed correct
        # if not: returns an error
        assert  current_wd == target_path, "Current working directory does not match with target directory"
        return print("current working directory:", current_wd)
    
    def download_data(self, data_url, file_name):
        """Download data from url

        Parameters
        ----------
        data_url : str
            URL from which data should be downloaded.
        file_name : str
            Name by which downloaded data file should be locally saved.

        Returns
        -------
        None.

        """
        # get data from url
        response = requests.get(data_url)
        with open(file_name, "wb") as file:
            file.write(response.content)
            
    # install pyarrow via pip install pyarrow
    def data_preprocessed(self, data_file):
        """Read and preprocess data 

        Parameters
        ----------
        data_file : str
            name of locally saved data file.

        Returns
        -------
        df_joined : polars.DataFrame
            Preprocessed data set with 84 observations and 6 variables (subject, 
            gender, scenario, attitude, frequency, mean_pitch).
        summaries : polars.DataFrame
            Mean pitch value grouped by attitude (informel, polite) and gender 
            (female, male).

        """
        # read data
        df = pl.from_pandas(pd.read_csv(data_file))
        # compute mean pitch values, grouped by gender and attitude
        summaries = df.group_by("attitude", "gender").agg(
            mean_pitch = pl.col("frequency").mean()
            )
        # join summaries and df columns together
        df_joined = df.join(summaries, on = ["gender", "attitude"], how = "inner")
        # relable attitude values
        df_joined = df_joined.with_columns(pl.lit(df["attitude"].map_dict({"pol": "polite", "inf": "informal"})).alias("attitude"))

        return (df_joined, summaries)
    
    def plot_data(self, df):
        """Scatterplot showing the relation between pitch in Hz and gender and 
        attitude.

        Parameters
        ----------
        df : polars.DataFrame
            Preprocessed data set with 84 observations and 6 variables (subject, 
            gender, scenario, attitude, frequency, mean_pitch).

        Returns
        -------
        matplotlib.plot

        """
        # create color sequence for grouping variable 
        # (to be passed into plot)
        cols = np.where(df["attitude"] == "polite", "lightblue", "orange")
        
        # initialie new plot
        fig, axs = plt.subplots(constrained_layout = True)
        # plot mean values
        axs.scatter(df["gender"],df["mean_pitch"], c = cols,edgecolors='black')
        # plot additionally individual observations
        sns.swarmplot(data = df,
                    x = "gender", y = "frequency", 
                    hue = "attitude",
                    alpha = 0.4, ax=axs)
        # relable x-axis
        axs.set_xticklabels(labels = ["Female", "Male"])
        axs.set_ylabel("pitch in Hz")
        plt.show()
       
    
# here we use pathlib.PureWindowsPath s.t. we don't need to care about
# direction of backslashes
target_path = pathlib.PureWindowsPath(r"C:\Users\flobo\OneDrive\Dokumente\Phd-teaching\IntroPython\python-intro\material\datasets") 
# data set
data_url = "http://www.bodowinter.com/tutorial/politeness_data.csv"    
data_file = "pitch_data.csv"

# initialize class and create a new instance
pol_data = PolitenessData(data_url, target_path, data_file)

help(PolitenessData)
dir(PolitenessData)
# set working directory
pol_data.set_cwd(target_path)

# download data set
pol_data.download_data(data_url, data_file)

# preprocess data set
df, df_sum = pol_data.data_preprocessed(data_file)

# plot data 
pol_data.plot_data(df)

# %% [markdown]
# ### Starting version control with git
#
# + Version control is a tool for managing changes to a set of files.
# + Why should we care about version control?
#     + Better kind of backup.
#     + Review history (“When did I introduce this bug?”).
#     + Restore older code versions.
#     + Ability to undo mistakes.
#     + Maintain several versions of the code at a time.
#     + Allow for collaboration
#
# + We will use **git** as version control system tool to manage source code history and **GitHub** for hosting service for Git repositories
#
# #### Initializing the repository
# + open your Terminal and select the path where you want to create your new git repository
#     + you can open the Windows Explorer (Finder in Mac) and go to the respective directory.
#         + Mac: control-click the folder in the path bar and choose Open in Terminal
#         + Windows: Right-click, further option and then choose Open Git Bash here
#     + Or copy&paste the path, go to the terminal and type `cd <path>` (replace <path> with your local path)
#
# + create a new folder which will be our git repository
#     + `mkdir example-project` (create a new folder)
#     + `cd example-project` (go into this folder)
#
# + Now, we will tell Git to track the content of this folder as a git “repository”.
#     + `git init --initial-branch=main`
# + We can list all files in a repository using `ls`. However, at the moment the repo is of course empty.
# + To get a feedback about the current status of our git repo we can use `git status`
#
# #### A first example
#
# + save the python script with the PolitenessData class from above in the newly created folder
# + we would like to keep track of its history therefore we have to `add` it
#     + `git add politeness_data.py`
# + Let's have once more a look into our status
#     + `git status`
# + Now, we need to tell Git to record the first version of this file in the history of changes
#     + `git commit -m "First commit of politeness data"`
#
# #### Configuring Git with your editor
# + If you don’t type in the log message directly with -m “Some message”, then an editor will pop up, to allow you to edit your message on the fly.
#     + get information about your current settings: `git config --get core.editor`
# + to configure `Notepad++`on Windows you'll need something like the following
#     + `git config --global core.editor "'C:/Program Files (x86)/Notepad++/notepad++.exe' -multiInst -nosession -noPlugin"`
# + However, you can use any editor that you prefer e.g., Windows users could use Notepad++, Mac users could use textmate or Sublime Text, Linux users could use vim, nano or emacs. (use `git config --global core.editor <editor>`)
# + Let us test whether it worked
#     + Create a new file in the folder example-project: `touch test.txt`
#     + Add file to track its history: `add test.txt`
#     + commit the changes (without message): `git commit`
#     + Now the respective editor should open and you can type a message: `Test file to test editor settings`
#     + Save the commit message and close your editor
#
# #### Commit logs
#
# + Git now has two changes in its history
#     + `git log`
#     + you see the author, message, date, and the hash code (e.g., commit d4c3c2014877d35f3181246893beac7fe85fb9d6)
# + the hash-code is a unique identifier of that particular revision (we will come back to this later)
#
# + Note that git will now tell us that our “working directory” is up-to-date with the repository: there are no changes to the files that aren’t recorded in the repository history:
#     + `git status`
#
# + Now, let's make some changes to our file politeness_data.py
#     + First, we create a new folder in our repo example-project: `mkdir data`
#     + Second, we change the variable `target_path` in politeness_data.py such that the downloaded data are save in this newly created folder
#     + Save the changes in politeness_data.py
# + Let's check again our status: `git status`
#     + We can now see that there is a change to “politeness_data.py” which is currently “not staged for commit”.
#     + If we do a git commit now nothing will happen.
#     + Git will only commit changes to files that you choose to include in each commit.
# + We can see the differences in the file with:
#     + `git diff`
#     + Deleted lines are prefixed with a minus, added lines prefixed with a plus.
#
# #### Staging a new file
# + To include the file in the next commit, we have a few choices. This is one of the things to be careful of with git: there are lots of ways to do similar things, and it can be hard to keep track of them all.
#     + `git add --update`:  This says “include in the next commit, all files which have ever been included before”
# + The “staging area” or “index” is the git jargon for the place which contains the list of changes which will be included in the next commit.
# + review of status
#     + `git status`
#     + We see now that the message has changed to "changes to be committed"
# + commit the changes
#     + `git commit -m "add data folder in repo and changed target_path to data folder"`
# + review log
#     + `git log`
# + If you want to see only the last commits, you can use:
#     + `git log | head`
# + If you want to have rather a summary output leaving out all the details, you can use:
#     + `git log --oneline`
#
# + Finally, let us delete the test.txt file from the repo as we don't need it anymore:
#     + `rm test.txt` (remove file)
#     + `git status` (checkout current status)
#     + `git add --update` (add changes to commit -> see how the message changes when you check again `git status`)
#     + `git commit -m "deleted test.txt file as not needed anymore"`
